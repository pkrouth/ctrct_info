# %% [markdown]
# ## Example of getting document Structure using pre-trained models

# %%
def get_document_structure(document):
    for sent in sentence_splitter.tokenize(document):
        t_df = srl_predictor.predict(sent)
        if len(t_df['verbs'])==0:
             print(sent)

# %%
doc = get_text_from_docs('./Sec_Annotation_PKR.docx')
get_document_structure(doc)
# Out:
# country and (ii) non-U.S.
# country.
# 2.
# GRANT OF SECURITY INTEREST.
# 3.
# REPRESENTATIONS AND WARRANTIES OF THE GRANTORS.
# (b) Location of Collateral.
# (c) Location of Grantors.
# (d) Instruments and Certificates.
# copyright registrations and copyright applications in the United States Copyright Office, and (y) U.S.
# (g) Account Debtors.
# (h) Intellectual Property.
# 4.
# COVENANTS OF GRANTORS.
# (b) Delivery of Instruments, Etc.
# (c) Chattel Paper.
# (d) Investment Property and Deposit Accounts.
# (e) Letter-of-Credit Rights.
# (f) Collateral In Possession of Third Parties.
# (g) Commercial Tort Claims.
# (h) Notice of Changes in Representations.
# (i) Insurance.
# (j) Transfer of Collateral.
# (k) Inventory.
# §546(h), or any successor section thereto.
# (l) Defense of Lender’s Rights.
# (m) Cash Management.
# (n) Additional Grantors.
# (o) Inspections.
# (p) Intellectual Property.
# (q) Power of Attorney.
# (r) Notices with Respect to Collateral.
# ...

# %%
doc = get_text_from_docs('/Users/prahlad/Smriti/Review/lawinsider_contracts/Avrobio, Inc. Employment Agreement.docx')
get_document_structure(doc)
# Out:
# EXHIBIT 10.10 AVROBIO, INC.
# Employment.
# (a) Term.
# (b) Position and Duties.
# 2.
# Compensation and Related Matters.
# (a) Base Salary.
# (b) Incentive Compensation.
# (c) Expenses.
# (d) Other Benefits.
# (e) Vacations.
# 3.
# Termination.
# (b) Disability.
# and the Americans with Disabilities Act, 42 U.S.C.
# §12101  et seq.
# (c) Termination by Company for Cause.
# (d) Termination Without Cause.
# (e) Termination by the Executive.
# (f) Notice of Termination.
# (g) Date of Termination.
# 4.
# Compensation Upon Termination.
# (a) Termination Generally.
# (b) Termination by the Company Without Cause or by the Executive with Good Reason.
# 5.
# Change in Control Payment.
# (a) Change in Control.
# (b) Additional Limitation.
# Reg.
# Reg.
# (c) Definitions.
# 6.
# Section 409A.
# 7.
# Confidential Information, Noncompetition and Cooperation.
# 9 (b) Third-Party Agreements and Rights.
# (c) Litigation and Regulatory Cooperation.
# (d) Relief.
# ...
